# %%
import os
import pandas as pd
import numpy as np

# %%
day_list = os.listdir('../data/update/20221116/day_update/')
min_list = os.listdir('../data/update/20221116/분봉/')

day_code_list = []
min_code_list = []
for day in day_list:
    day_code_list.append(day.split('_')[-1])

for min in min_list:
    min_code_list.append(min.split('_')[-1])

print(len(day_code_list), len(min_code_list))

test = []
min_unique = []
for code_day in day_code_list:
    if code_day not in min_code_list:
        min_unique.append(code_day)

    
    # elif code_day in min_code_list:
    #     test.append(code_day)
    # else:
    #     min_unique.append(code_day)

test_ = []
day_unique = []
for code_min in min_code_list:
    if code_min not in day_code_list:
        day_unique.append(code_min)
    # elif code_min in day_code_list:
    #     test_.append(code_min)
    # else:
    #     day_unique.append(code_min)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4392\2140557129.py in <module>
# ----> 1 day_list = os.listdir('../data/update/20221116/day_update/')
#       2 min_list = os.listdir('../data/update/20221116/분봉/')
#       3
#       4 day_code_list = []
#       5 min_code_list = []
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '../data/update/20221116/day_update/'

# %%
len(day_code_list), len(min_code_list)
# Out:
# (2425, 2422)

# %%
min_unique, day_unique
# Out:
# (['신풍제지.csv', '비보존 제약.csv', '더코디.csv'], [])

# %%
len(test), len(test_)
# Out:
# (2425, 2422)

# %%
day_list = os.listdir('../data/update/20221116/day_update/')
min_list = os.listdir('../data/update/20221116/분봉/')

day_code_list = []
min_code_list = []
for day in day_list:
    day_code_list.append(day.split('_')[-2])

for min in min_list:
    min_code_list.append(min.split('_')[-2])

print(list(set(min_code_list).difference(day_code_list)))
# Out:
# []

# %%
from tqdm import tqdm

modify_list = os.listdir('../data/20221121/min_fillrow/')
# Out:
#  23%|██▎       | 567/2422 [45:27<2:28:41,  4.81s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\TJ\.conda\envs\tf2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\TJ\.conda\envs\tf2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\TJ\.conda\envs\tf2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '누적거래량'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4392\3060967544.py in <module>
#      14
#      15     temp_df1 = pd.concat([temp_df1, volume], axis=1)
# ---> 16     temp_df1['누적체결매수수량'] = temp_df1['누적거래량'] - temp_df1['누적체결매도수량']
#      17     temp_df1.drop(columns=['누적거래량','Unnamed: 0'], axis=1)
#      18     colum_1 = temp_df1[temp_df1.columns[0:10]]
#
# c:\Users\TJ\.conda\envs\tf2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# c:\Users\TJ\.conda\envs\tf2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '누적거래량'

# %%
for stock in tqdm(modify_list[567:]):
    temp_df = pd.read_csv(f'../data/20221121/min_fillrow/{stock}')

    if temp_df['시가'].isnull().sum() < 194571:
        temp_df1 = temp_df.dropna()

        volume = pd.DataFrame()
        for day in temp_df1.날짜.unique():
            temp = pd.DataFrame()
            temp['누적거래량'] = temp_df1[temp_df1['날짜'] == day][::-1]['거래량'].cumsum()
            volume = pd.concat([volume, temp[::-1]], axis=0)

        temp_df1 = pd.concat([temp_df1, volume], axis=1)
        temp_df1['누적체결매수수량'] = temp_df1['누적거래량'] - temp_df1['누적체결매도수량']
        temp_df1.drop(columns=['누적거래량','Unnamed: 0'], axis=1)
        colum_1 = temp_df1[temp_df1.columns[0:10]]
        colum_2 = temp_df1[temp_df1.columns[-1]]
        colum_3 = temp_df1[temp_df1.columns[10:-2]]

        temp_df2 = pd.concat([colum_1, colum_2, colum_3], axis=1)

        temp_df2.to_csv(f'../data/20221121/modify_fillrow/{stock}', encoding='utf-8 sig', index=False)
# Out:
# 100%|██████████| 1855/1855 [2:13:23<00:00,  4.31s/it]

# %%
min_fill_path = '../data/20221121/modify_fillrow/'
day_update_path = '../data/20221121/day_update/'
concat_path = '../data/20221121/concat/'

from tqdm import tqdm

def min_day_concat_info(min_fill_path = min_fill_path, day_update_path=day_update_path, concat_path= concat_path):
    min_fill_list = os.listdir(min_fill_path)
    day_update_list = os.listdir(day_update_path)
    for min_df, day_df in tqdm(zip(min_fill_list, day_update_list)):
        stock_min_df = pd.read_csv(f'{min_fill_path}{min_df}', encoding='utf-8 sig', index_col=0)
        stock_day_df = pd.read_csv(f'{day_update_path}{day_df}', encoding='utf-8 sig')
        
        input_list = ['전일대비','상장주식수','시가총액','외국인주문한도수량'
                    ,'외국인주문가능수량','외국인현보유수량','외국인현보유비율'
                    ,'수정주가일자','수정주가비율','기관순매수량','기관누적순매수량'
                    ,'등락주선','등락비율','예탁금','주식회전율','거래성립률']                                  
        list_ = ['시간','시가','고가','저가','종가','거래량','거래대금','누적체결매도수량'
                 ,'등락주선','등락비율','예탁금','주식회전율','거래성립률']
            
        stock_min_df = stock_min_df.drop(input_list, axis=1)
        stock_day_df = stock_day_df.drop(list_, axis=1)
        
        stock_day_df = stock_day_df.rename(columns={'Unnamed: 0':'날짜'})
        concat_df = pd.merge(stock_min_df, stock_day_df,on='날짜', how='left')
        
        concat_df.to_csv(f'{concat_path}concat_{min_df}', encoding='utf-8 sig', index=False)          
        
    return concat_df

# %%
min_day_concat_info()
# Out:
# 2406it [2:16:46,  3.41s/it]
#               날짜    시간       시가       고가       저가       종가        거래량  \
# 0       20221121  1530   3820.0   3820.0   3820.0   3820.0    23608.0
# 1       20221121  1520   3830.0   3840.0   3830.0   3830.0    13735.0
# 2       20221121  1519   3840.0   3840.0   3835.0   3835.0     1755.0
# 3       20221121  1518   3840.0   3840.0   3840.0   3840.0      171.0
# 4       20221121  1517   3835.0   3840.0   3830.0   3835.0      922.0
# ...          ...   ...      ...      ...      ...      ...        ...
# 190054  20210316   905  16400.0  16850.0  16400.0  16850.0        0.0
# 190055  20210316   904  16400.0  16850.0  16400.0  16850.0    96995.0
# 190056  20210316   903  15350.0  16500.0  15350.0  16400.0  2854538.0
# 190057  20210316   902  15000.0  15100.0  15000.0  15100.0        0.0
# 190058  20210316   901  15000.0  15100.0  15000.0  15100.0   924994.0
#
#                 거래대금   누적체결매수수량  누적체결매도수량  ...     상장주식수           시가총액  \
# 0       9.018200e+07   166761.0  454624.0  ...  98827000   377519000000
# 1       5.262100e+07   143153.0  454624.0  ...  98827000   377519000000
# 2       6.733000e+06   142102.0  441940.0  ...  98827000   377519000000
# 3       6.560000e+05   141312.0  440975.0  ...  98827000   377519000000
# 4       3.535000e+06   141141.0  440975.0  ...  98827000   377519000000
# ...              ...        ...       ...  ...       ...            ...
# 190054  0.000000e+00  3431094.0  445433.0  ...  98392000  1411925000000
# 190055  1.611793e+09  3431094.0  445433.0  ...  98392000  1411925000000
# 190056  4.469986e+10  3370904.0  408628.0  ...  98392000  1411925000000
# 190057  0.000000e+00   923347.0    1647.0  ...  98392000  1411925000000
# 190058  1.387501e+10   923347.0    1647.0  ...  98392000  1411925000000
#
#         외국인주문한도수량  외국인주문가능수량  외국인현보유수량  외국인현보유비율    수정주가일자  수정주가비율   기관순매수량  \
# 0        98827465   96449364   2378101      2.41  20221121   100.0        0
# 1        98827465   96449364   2378101      2.41  20221121   100.0        0
# 2        98827465   96449364   2378101      2.41  20221121   100.0        0
# 3        98827465   96449364   2378101      2.41  20221121   100.0        0
# 4        98827465   96449364   2378101      2.41  20221121   100.0        0
# ...           ...        ...       ...       ...       ...     ...      ...
# 190054   98392010   98073830    318180      0.32  20210316   100.0 -2114735
# 190055   98392010   98073830    318180      0.32  20210316   100.0 -2114735
# 190056   98392010   98073830    318180      0.32  20210316   100.0 -2114735
# 190057   98392010   98073830    318180      0.32  20210316   100.0 -2114735
# 190058   98392010   98073830    318180      0.32  20210316   100.0 -2114735
#
#         기관누적순매수량
# 0      -23446016
# 1      -23446016
# 2      -23446016
# 3      -23446016
# 4      -23446016
# ...          ...
# 190054  -2114735
# 190055  -2114735
# 190056  -2114735
# 190057  -2114735
# 190058  -2114735
#
# [190059 rows x 21 columns]
