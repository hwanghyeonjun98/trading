# %%
from module import connection, get, save, search, update

# %%
empty_list = get.get_day_empty_list()

# %%
len(empty_list)
# Out:
# 2422

# %%
# COM2는 순서 역순으로 실행할 것 empty_list[::-1]
for code in empty_list[::-1]:
    save.save_day_stock_info_auto('A'+code,'20221108','D')
# Out:
# 20221103
# (4, 24)
# ['A238490', '힘스'] Count : 0, 남은 요청 횟수 :59
# 20221029
# (8, 24)
# ['A238490', '힘스'] Count : 1, 남은 요청 횟수 :58
# 20221024
# (13, 24)
# ['A238490', '힘스'] Count : 2, 남은 요청 횟수 :57
# 20221019
# (17, 24)
# ['A238490', '힘스'] Count : 3, 남은 요청 횟수 :56
# 20221014
# (21, 24)
# ['A238490', '힘스'] Count : 4, 남은 요청 횟수 :55
# 20221009
# (25, 24)
# ['A238490', '힘스'] Count : 5, 남은 요청 횟수 :54
# 20221004
# (29, 24)
# ['A238490', '힘스'] Count : 6, 남은 요청 횟수 :53
# 20220929
# (32, 24)
# ['A238490', '힘스'] Count : 7, 남은 요청 횟수 :52
# 20220924
# (36, 24)
# ['A238490', '힘스'] Count : 8, 남은 요청 횟수 :51
# 20220919
# (41, 24)
# ['A238490', '힘스'] Count : 9, 남은 요청 횟수 :50
# 20220914
# (45, 24)
# ['A238490', '힘스'] Count : 10, 남은 요청 횟수 :49
# 20220909
# (47, 24)
# ['A238490', '힘스'] Count : 11, 남은 요청 횟수 :48
# 20220904
# (51, 24)
# ['A238490', '힘스'] Count : 12, 남은 요청 횟수 :47
# 20220830
# (55, 24)
# ['A238490', '힘스'] Count : 13, 남은 요청 횟수 :46
# 20220825
# (59, 24)
# ['A238490', '힘스'] Count : 14, 남은 요청 횟수 :45
# ...
